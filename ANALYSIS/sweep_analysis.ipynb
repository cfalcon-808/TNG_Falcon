# %%
import pandas as pd

# %%
sweep_results_df = pd.read_csv("artifacts\eval_sweeps\sweep_results_20260308_015821.csv")
sweep_results_df
# Out:
#                       tiger_name           goat_name  \
# 0            robust_tiger_030726  normal_goat_030726
# 1  best_tiger_vs_normal_goat_10M  normal_goat_030726
# 2   best_tiger_vs_smart_goat_10M  normal_goat_030726
# 3            robust_tiger_030726   smart_goat_030726
# 4  best_tiger_vs_normal_goat_10M   smart_goat_030726
# 5   best_tiger_vs_smart_goat_10M   smart_goat_030726
# 6            robust_tiger_030726  robust_goat_030726
# 7  best_tiger_vs_normal_goat_10M  robust_goat_030726
# 8   best_tiger_vs_smart_goat_10M  robust_goat_030726
#
#                                              matchup  episodes  goat_wins  \
# 0          normal_goat_030726 vs robust_tiger_030726       100          0
# 1  normal_goat_030726 vs best_tiger_vs_normal_goa...       100          0
# 2  normal_goat_030726 vs best_tiger_vs_smart_goat...       100          0
# 3           smart_goat_030726 vs robust_tiger_030726       100          0
# ...
